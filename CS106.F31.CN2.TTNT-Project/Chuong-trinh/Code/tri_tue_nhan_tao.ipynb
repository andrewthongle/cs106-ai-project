# %% [markdown]
# # Trí tuệ nhân tạo: phân loại trực tiếp SAFE/TOXIC trên ViHSD
#
# Ground truth được đổi **trước khi fit**: `CLEAN → SAFE`, `OFFENSIVE/HATE → TOXIC`.
# Notebook hiển thị thống kê dữ liệu, metrics tổng hợp/từng lớp, confusion matrix, thời gian, lịch sử huấn luyện và phân tích lỗi.
# Không hiển thị bình luận thô từ ViHSD; demo chỉ dùng câu tự tạo. Bài toán là sàng lọc ngôn từ độc hại có human review, không phải phát hiện tin giả.
#
# **Phạm vi kết quả:** cả 5 mô hình được so sánh trên **dev** khi chạy `FULL_WITH_NEURAL`.
# Chỉ **baseline đã khóa** được đánh giá trên **test** và dùng cho demo. Nhánh neural là thí nghiệm bổ sung trên train/dev, không thay đổi model đã khóa.
#
# **Cấu trúc:** logic nằm trong `vihsd_ai/*.py`; notebook dùng để cấu hình, thử nghiệm và trình bày.
# **Kết quả đã lưu:** các output bên dưới được giữ nguyên từ lần chạy trước khi tách code; chưa chạy lại phiên bản module. Mở notebook để xem, chỉ Run all khi muốn tạo thí nghiệm mới.

# %% [markdown]
# ## 1. Cấu hình chế độ chạy
# `SMOKE` chỉ dùng QA; báo cáo dùng `FULL` hoặc `FULL_WITH_NEURAL`. Nhánh neural nên chạy trên GPU.
# Chạy **Runtime → Run all** từ đầu. Mỗi lần khởi tạo sẽ tạo một thư mục kết quả riêng và in đường dẫn.
# Chỉ xem/trình bày kết quả đã lưu thì không cần chạy cell hay cài dependency.

# %%
RUN_MODE = "FULL_WITH_NEURAL"  # @param ["SMOKE", "FULL", "FULL_WITH_NEURAL"]
SEED = 42
CONFIRM_TEST_AFTER_LOCK = True
NEURAL_EPOCHS = 3
assert NEURAL_EPOCHS >= 1
assert RUN_MODE in {"SMOKE", "FULL", "FULL_WITH_NEURAL"}
print(f"RUN_MODE={RUN_MODE}, seed={SEED}")
# Out:
# RUN_MODE=FULL_WITH_NEURAL, seed=42

# %% [markdown]
# ## 2. Nạp source từ repo, cài dependency và khởi tạo lần chạy
# Colab cần thư mục `vihsd_ai/` cùng phiên bản notebook. Cell dưới tự clone repo nếu chưa có; với thay đổi chưa đẩy lên GitHub, upload repo mới vào `/content/cs106-ai-project` trước khi chạy.

# %%
from pathlib import Path
import subprocess
import sys

# Tìm thư mục chứa package vihsd_ai/.
# Dò theo thứ tự: thư mục hiện tại -> các thư mục cha -> các thư mục con một cấp.
# Nhờ dò cả thư mục con nên chỉ cần upload nguyên thư mục Code/ vào /content là chạy được.
def _find_project():
    here = Path.cwd()
    candidates = [here, *here.parents]
    try:
        candidates += sorted(d for d in here.iterdir() if d.is_dir() and not d.name.startswith("."))
    except OSError:
        pass
    # Ưu tiên bản có đủ neural_eval.py (bản mới), tránh nhầm với checkout cũ.
    for p in candidates:
        if (p / "vihsd_ai" / "neural_eval.py").exists():
            return p
    for p in candidates:
        if (p / "vihsd_ai" / "__init__.py").exists():
            return p
    return None

PROJECT_DIR = _find_project()
if PROJECT_DIR is None and Path("/content").exists():
    PROJECT_DIR = Path("/content/cs106-ai-project")
    if not PROJECT_DIR.exists():
        print("Không thấy code đã upload, đang tải từ GitHub...", flush=True)
        subprocess.run(["git", "clone", "--depth", "1",
                        "https://github.com/andrewthongle/cs106-ai-project.git", str(PROJECT_DIR)], check=True)
if PROJECT_DIR is None or not (PROJECT_DIR / "vihsd_ai").is_dir():
    raise FileNotFoundError(
        "Không tìm thấy package vihsd_ai/. Colab: upload thư mục Code/ vào /content rồi chạy lại cell này.")

# Dọn đường dẫn và module đã nạp của lần chạy trước, để không dùng nhầm bản cũ.
for stale in [q for q in sys.path if q != str(PROJECT_DIR) and (Path(q) / "vihsd_ai").is_dir()]:
    sys.path.remove(stale)
for cached in [m for m in list(sys.modules) if m == "vihsd_ai" or m.startswith("vihsd_ai.")]:
    del sys.modules[cached]
if str(PROJECT_DIR) not in sys.path:
    sys.path.insert(0, str(PROJECT_DIR))

print(f"Dùng code tại: {PROJECT_DIR}")
print(f"  neural_eval.py: {'có' if (PROJECT_DIR / 'vihsd_ai' / 'neural_eval.py').exists() else 'KHÔNG CÓ (bản cũ)'}")

requirements = "requirements-neural.txt" if RUN_MODE == "FULL_WITH_NEURAL" else "requirements.txt"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-r", str(PROJECT_DIR / requirements)])
# Out:
# Không thấy code đã upload, đang tải từ GitHub...
# Dùng code tại: /content/cs106-ai-project
#   neural_eval.py: có
# 0

# %%
from vihsd_ai import RunConfig, create_run
from vihsd_ai.data import prepare_dataset, load_train_dev
from vihsd_ai.baselines import make_baselines, train_baselines, freeze_baseline, evaluate_test
from vihsd_ai.analysis import analyze_errors, predict_examples, system_decision
from vihsd_ai.neural import prepare_neural, train_bilstm, train_phobert
from vihsd_ai.neural_eval import evaluate_neural_test
from vihsd_ai.reporting import Reports

config = RunConfig(run_mode=RUN_MODE, seed=SEED, neural_epochs=NEURAL_EPOCHS)
run = create_run(config)
prepare_dataset(run)
# Out:
# ViHSD checksum verified
# Thư mục kết quả lần chạy này: /content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural

# %%
reports = Reports(run)

# %% [markdown]
# ## 3. Nạp train/dev và đổi nhãn trước khi huấn luyện
# Chưa mở test tại bước này. Bảng hiển thị cả số lượng và tỷ lệ SAFE/TOXIC.

# %%
train_df, dev_df = load_train_dev(run)
reports.split_overview(train_df, dev_df)
# Out:
# Quy mô dữ liệu train/dev
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>split</th>
#       <th>rows</th>
#       <th>SAFE</th>
#       <th>TOXIC</th>
#       <th>TOXIC ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>train</td>
#       <td>24048</td>
#       <td>19886</td>
#       <td>4162</td>
#       <td>0.1731</td>
#     </tr>
#     <tr>
#       <td>dev</td>
#       <td>2672</td>
#       <td>2190</td>
#       <td>482</td>
#       <td>0.1804</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ## 4. Audit dữ liệu và phân bố
# Bảng thống kê chứa số lượng, nhãn gốc/nhị phân, độ dài ký tự, URL và số fingerprint duy nhất.
# Histogram dùng trục X logarithm `log(1 + độ dài)` để hiển thị cả câu ngắn lẫn dài, không cắt bỏ đuôi phân bố.

# %%
audit = reports.audit_train_dev(train_df, dev_df)
# Out:
# Thống kê tổng hợp; độ dài tính bằng ký tự
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>split</th>
#       <th>rows</th>
#       <th>contains_url</th>
#       <th>empty_texts</th>
#       <th>unique_fingerprints</th>
#       <th>duplicate_rows</th>
#       <th>length_min</th>
#       <th>length_median</th>
#       <th>length_mean</th>
#       <th>length_p95</th>
#       <th>length_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>train</td>
#       <td>24048</td>
#       <td>19</td>
#       <td>2</td>
#       <td>22558</td>
#       <td>1490</td>
#       <td>0</td>
#       <td>33.0000</td>
#       <td>49.2834</td>
#       <td>136.0000</td>
#       <td>20816</td>
#     </tr>
#     <tr>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2650</td>
#       <td>22</td>
#       <td>1</td>
#       <td>33.0000</td>
#       <td>47.9042</td>
#       <td>141.4500</td>
#       <td>583</td>
#     </tr>
#   </tbody>
# </table></div>
# Phân bố nhãn gốc và nhãn nhị phân
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>split</th>
#       <th>label_type</th>
#       <th>label</th>
#       <th>count</th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>train</td>
#       <td>source_distribution</td>
#       <td>CLEAN</td>
#       <td>19886</td>
#       <td>0.8269</td>
#     </tr>
#     <tr>
#       <td>train</td>
#       <td>source_distribution</td>
#       <td>HATE</td>
#       <td>2556</td>
#       <td>0.1063</td>
#     </tr>
#     <tr>
#       <td>train</td>
#       <td>source_distribution</td>
#       <td>OFFENSIVE</td>
#       <td>1606</td>
#       <td>0.0668</td>
#     </tr>
#     <tr>
#       <td>train</td>
#       <td>binary_distribution</td>
#       <td>SAFE</td>
#       <td>19886</td>
#       <td>0.8269</td>
#     </tr>
#     <tr>
#       <td>train</td>
#       <td>binary_distribution</td>
#       <td>TOXIC</td>
#       <td>4162</td>
#       <td>0.1731</td>
#     </tr>
#     <tr>
#       <td>dev</td>
#       <td>source_distribution</td>
#       <td>CLEAN</td>
#       <td>2190</td>
#       <td>0.8196</td>
#     </tr>
#     <tr>
#       <td>dev</td>
#       <td>source_distribution</td>
#       <td>HATE</td>
#       <td>270</td>
#       <td>0.1010</td>
#     </tr>
#     <tr>
#       <td>dev</td>
#       <td>source_distribution</td>
#       <td>OFFENSIVE</td>
#       <td>212</td>
#       <td>0.0793</td>
#     </tr>
#     <tr>
#       <td>dev</td>
#       <td>binary_distribution</td>
#       <td>SAFE</td>
#       <td>2190</td>
#       <td>0.8196</td>
#     </tr>
#     <tr>
#       <td>dev</td>
#       <td>binary_distribution</td>
#       <td>TOXIC</td>
#       <td>482</td>
#       <td>0.1804</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ## 5. Tiền xử lý social text tiếng Việt
# Unicode/lowercase → URL → icon/emoji → ký tự lặp → teen code → `underthesea` → stopword.
# Từ phủ định được giữ. TF-IDF và từ vựng chỉ fit trên train.

# %%
from vihsd_ai.preprocessing import SocialPreprocessor
# Dùng SocialPreprocessor().transform([...]) để thử riêng với câu tự tạo.

# %% [markdown]
# ## 6–7. Huấn luyện, đánh giá train/dev và chọn baseline
# Xếp hạng bằng **dev Macro-F1 → dev TOXIC Recall → tên model** (không làm tròn trước khi chọn).
# Hiển thị metrics đầy đủ, khoảng cách train–dev, thời gian fit/đánh giá và confusion matrix trên cả hai split.

# %%
# Có thể thay/thêm estimator trong models để thử nghiệm; selection vẫn dùng dev.
models = make_baselines(seed=SEED)
baselines = train_baselines(train_df, dev_df, seed=SEED, models=models)
# Out:
# Đang fit multinomial_nb...
# multinomial_nb: fit=15.6s | dev Macro-F1=0.6808 | dev TOXIC Recall=0.2946
# Đang fit logistic_regression...
# logistic_regression: fit=15.2s | dev Macro-F1=0.7911 | dev TOXIC Recall=0.7656
# Đang fit linear_svc...
# linear_svc: fit=16.1s | dev Macro-F1=0.7923 | dev TOXIC Recall=0.7241
# Baseline được chọn để khóa/test/demo: linear_svc

# %%
baseline_overview = reports.baselines(baselines)
# Out:
# Xếp hạng baseline; thời gian tính bằng giây
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>train_macro_f1</th>
#       <th>dev_macro_f1</th>
#       <th>train_minus_dev_f1</th>
#       <th>dev_toxic_recall</th>
#       <th>fit_seconds</th>
#       <th>evaluation_seconds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_svc</td>
#       <td>0.9602</td>
#       <td>0.7923</td>
#       <td>0.1679</td>
#       <td>0.7241</td>
#       <td>16.1263</td>
#       <td>16.4925</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>0.9148</td>
#       <td>0.7911</td>
#       <td>0.1237</td>
#       <td>0.7656</td>
#       <td>15.1772</td>
#       <td>16.8759</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>0.8319</td>
#       <td>0.6808</td>
#       <td>0.1511</td>
#       <td>0.2946</td>
#       <td>15.5650</td>
#       <td>17.2299</td>
#     </tr>
#   </tbody>
# </table></div>
# Metrics tổng hợp (thang 0–1)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>samples</th>
#       <th>accuracy</th>
#       <th>macro_precision</th>
#       <th>macro_recall</th>
#       <th>macro_f1</th>
#       <th>weighted_precision</th>
#       <th>weighted_recall</th>
#       <th>weighted_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_svc</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9761</td>
#       <td>0.9411</td>
#       <td>0.9826</td>
#       <td>0.9602</td>
#       <td>0.9786</td>
#       <td>0.9761</td>
#       <td>0.9767</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8690</td>
#       <td>0.7767</td>
#       <td>0.8125</td>
#       <td>0.7923</td>
#       <td>0.8791</td>
#       <td>0.8690</td>
#       <td>0.8730</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9465</td>
#       <td>0.8848</td>
#       <td>0.9566</td>
#       <td>0.9148</td>
#       <td>0.9561</td>
#       <td>0.9465</td>
#       <td>0.9488</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8630</td>
#       <td>0.7691</td>
#       <td>0.8250</td>
#       <td>0.7911</td>
#       <td>0.8814</td>
#       <td>0.8630</td>
#       <td>0.8694</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9202</td>
#       <td>0.9366</td>
#       <td>0.7796</td>
#       <td>0.8319</td>
#       <td>0.9232</td>
#       <td>0.9202</td>
#       <td>0.9116</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8641</td>
#       <td>0.8625</td>
#       <td>0.6421</td>
#       <td>0.6808</td>
#       <td>0.8637</td>
#       <td>0.8641</td>
#       <td>0.8355</td>
#     </tr>
#   </tbody>
# </table></div>
# Precision / Recall / F1 / Support từng lớp
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>label</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_svc</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9984</td>
#       <td>0.9727</td>
#       <td>0.9854</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.8838</td>
#       <td>0.9926</td>
#       <td>0.9350</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9368</td>
#       <td>0.9009</td>
#       <td>0.9185</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.6166</td>
#       <td>0.7241</td>
#       <td>0.6660</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9938</td>
#       <td>0.9412</td>
#       <td>0.9668</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.7757</td>
#       <td>0.9721</td>
#       <td>0.8629</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9449</td>
#       <td>0.8845</td>
#       <td>0.9137</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.5932</td>
#       <td>0.7656</td>
#       <td>0.6685</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9160</td>
#       <td>0.9947</td>
#       <td>0.9538</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.9572</td>
#       <td>0.5644</td>
#       <td>0.7101</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.8644</td>
#       <td>0.9895</td>
#       <td>0.9227</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.8606</td>
#       <td>0.2946</td>
#       <td>0.4389</td>
#       <td>482</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ## 8. Khóa baseline/config trước khi mở test

# %%
selection = freeze_baseline(run, baselines)
reports.selection(selection)
# Out:
# Đã khóa baseline trước khi mở test: linear_svc
#
# Manifest lần chạy
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>setting</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>run_id</td>
#       <td>20260920T101602724213Z_full_with_neural</td>
#     </tr>
#     <tr>
#       <td>seed</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <td>neural_epochs</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>run_mode</td>
#       <td>FULL_WITH_NEURAL</td>
#     </tr>
#     <tr>
#       <td>dataset_commit</td>
#       <td>70fe50c9c94145e3b9be5614a048cbd5b480fa54</td>
#     </tr>
#     <tr>
#       <td>dataset_sha256</td>
#       <td>1d823c4c86a8aede83555c64da4e1be24146967aac6b30cdaf8603d4910f328d</td>
#     </tr>
#     <tr>
#       <td>test_loaded_during_training</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>result_status</td>
#       <td>reproduction_post_hoc</td>
#     </tr>
#     <tr>
#       <td>label_mapping_before_fit.CLEAN</td>
#       <td>SAFE</td>
#     </tr>
#     <tr>
#       <td>label_mapping_before_fit.OFFENSIVE</td>
#       <td>TOXIC</td>
#     </tr>
#     <tr>
#       <td>label_mapping_before_fit.HATE</td>
#       <td>TOXIC</td>
#     </tr>
#   </tbody>
# </table></div>
# Khóa lựa chọn và checksum trước test
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>setting</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>locked</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>locked_before_test</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td>test_opened</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>selected_model</td>
#       <td>linear_svc</td>
#     </tr>
#     <tr>
#       <td>artifact.path</td>
#       <td>linear_svc.joblib</td>
#     </tr>
#     <tr>
#       <td>artifact.sha256</td>
#       <td>5f73bb7f4ad13c850bbe937cea1fdef2e13938ba7417a17935a8882828caa81e</td>
#     </tr>
#     <tr>
#       <td>dev_results.path</td>
#       <td>dev_results.json</td>
#     </tr>
#     <tr>
#       <td>dev_results.sha256</td>
#       <td>342eab5caf208cc2231507937043fccff5fa5d32edd2d7acdf6e1d5835e0c17f</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ## 9–10. Test của baseline đã khóa
# Tên model xuất hiện trên các bảng và biểu đồ. Test không tham gia fit hay chọn model.
# Báo cáo có Accuracy, macro/weighted Precision–Recall–F1 và Precision–Recall–F1–Support của từng lớp.

# %%
test = evaluate_test(run, confirm=CONFIRM_TEST_AFTER_LOCK)
reports.test_summary(test)
# Out:
# TEST • linear_svc • 6,680 mẫu • dự đoán 4.73s
#
# Thống kê tổng hợp; độ dài tính bằng ký tự
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>split</th>
#       <th>rows</th>
#       <th>contains_url</th>
#       <th>empty_texts</th>
#       <th>unique_fingerprints</th>
#       <th>duplicate_rows</th>
#       <th>length_min</th>
#       <th>length_median</th>
#       <th>length_mean</th>
#       <th>length_p95</th>
#       <th>length_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>test</td>
#       <td>6680</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6576</td>
#       <td>104</td>
#       <td>1</td>
#       <td>33.0000</td>
#       <td>48.0138</td>
#       <td>141.0500</td>
#       <td>1762</td>
#     </tr>
#   </tbody>
# </table></div>
# Phân bố nhãn gốc và nhãn nhị phân
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>split</th>
#       <th>label_type</th>
#       <th>label</th>
#       <th>count</th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>test</td>
#       <td>source_distribution</td>
#       <td>CLEAN</td>
#       <td>5548</td>
#       <td>0.8305</td>
#     </tr>
#     <tr>
#       <td>test</td>
#       <td>source_distribution</td>
#       <td>HATE</td>
#       <td>688</td>
#       <td>0.1030</td>
#     </tr>
#     <tr>
#       <td>test</td>
#       <td>source_distribution</td>
#       <td>OFFENSIVE</td>
#       <td>444</td>
#       <td>0.0665</td>
#     </tr>
#     <tr>
#       <td>test</td>
#       <td>binary_distribution</td>
#       <td>SAFE</td>
#       <td>5548</td>
#       <td>0.8305</td>
#     </tr>
#     <tr>
#       <td>test</td>
#       <td>binary_distribution</td>
#       <td>TOXIC</td>
#       <td>1132</td>
#       <td>0.1695</td>
#     </tr>
#   </tbody>
# </table></div>
# Metrics tổng hợp (thang 0–1)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>samples</th>
#       <th>accuracy</th>
#       <th>macro_precision</th>
#       <th>macro_recall</th>
#       <th>macro_f1</th>
#       <th>weighted_precision</th>
#       <th>weighted_recall</th>
#       <th>weighted_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_svc</td>
#       <td>test</td>
#       <td>6680</td>
#       <td>0.8683</td>
#       <td>0.7654</td>
#       <td>0.7948</td>
#       <td>0.7785</td>
#       <td>0.8765</td>
#       <td>0.8683</td>
#       <td>0.8717</td>
#     </tr>
#   </tbody>
# </table></div>
# Precision / Recall / F1 / Support từng lớp
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>label</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_svc</td>
#       <td>test</td>
#       <td>SAFE</td>
#       <td>0.9335</td>
#       <td>0.9059</td>
#       <td>0.9195</td>
#       <td>5548</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>test</td>
#       <td>TOXIC</td>
#       <td>0.5972</td>
#       <td>0.6837</td>
#       <td>0.6376</td>
#       <td>1132</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
reports.test_plots(test)

# %% [markdown]
# ## 11. Phân tích lỗi test
# Hiển thị số lượng FP/FN, tỷ lệ tương ứng, lỗi theo độ dài và fingerprint của tối đa 20 lỗi đầu tiên.
# Tỷ lệ lỗi theo nhóm luôn đi kèm số mẫu; nhóm rỗng hiển thị N/A. Không in nội dung bình luận ViHSD.

# %%
errors = analyze_errors(test)
reports.errors(errors)
# Out:
# linear_svc • 880/6,680 lỗi test
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>outcome</th>
#       <th>count</th>
#       <th>fraction_of_test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>TN: SAFE → SAFE</td>
#       <td>5026</td>
#       <td>0.7524</td>
#     </tr>
#     <tr>
#       <td>FP: SAFE → TOXIC</td>
#       <td>522</td>
#       <td>0.0781</td>
#     </tr>
#     <tr>
#       <td>FN: TOXIC → SAFE</td>
#       <td>358</td>
#       <td>0.0536</td>
#     </tr>
#     <tr>
#       <td>TP: TOXIC → TOXIC</td>
#       <td>774</td>
#       <td>0.1159</td>
#     </tr>
#   </tbody>
# </table></div>
# Tỷ lệ lỗi và mẫu số
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>rate</th>
#       <th>value</th>
#       <th>denominator</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>False positive rate: FP / số SAFE thật</td>
#       <td>0.0941</td>
#       <td>5548</td>
#     </tr>
#     <tr>
#       <td>False negative rate: FN / số TOXIC thật</td>
#       <td>0.3163</td>
#       <td>1132</td>
#     </tr>
#     <tr>
#       <td>Error rate: (FP+FN) / toàn bộ test</td>
#       <td>0.1317</td>
#       <td>6680</td>
#     </tr>
#   </tbody>
# </table></div>
# Lỗi theo độ dài ký tự
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>length_chars</th>
#       <th>samples</th>
#       <th>errors</th>
#       <th>error_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0–50</td>
#       <td>4715</td>
#       <td>498</td>
#       <td>0.1056</td>
#     </tr>
#     <tr>
#       <td>51–100</td>
#       <td>1325</td>
#       <td>230</td>
#       <td>0.1736</td>
#     </tr>
#     <tr>
#       <td>101–200</td>
#       <td>493</td>
#       <td>117</td>
#       <td>0.2373</td>
#     </tr>
#     <tr>
#       <td>201–500</td>
#       <td>145</td>
#       <td>34</td>
#       <td>0.2345</td>
#     </tr>
#     <tr>
#       <td>&gt;500</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0.5000</td>
#     </tr>
#   </tbody>
# </table></div>
# Tối đa 20 lỗi đầu tiên (định danh bằng fingerprint)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>fingerprint_prefix</th>
#       <th>truth</th>
#       <th>prediction</th>
#       <th>length_chars</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>80480095bee5bd06</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <td>fff22636d97bf2b3</td>
#       <td>TOXIC</td>
#       <td>SAFE</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td>585a23f8c740e503</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>3dedb62caa9cd9bf</td>
#       <td>TOXIC</td>
#       <td>SAFE</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <td>2749840ed10675f0</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>73</td>
#     </tr>
#     <tr>
#       <td>7380e7f5760ccb5a</td>
#       <td>TOXIC</td>
#       <td>SAFE</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <td>7a481e843079c9e8</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td>25937a5fb94f42eb</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <td>690ea432f093be2a</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>c9d8b26897538077</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <td>7cf5176be1db258c</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>177</td>
#     </tr>
#     <tr>
#       <td>4c2825aaecaea063</td>
#       <td>TOXIC</td>
#       <td>SAFE</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <td>7b9be1b15663f921</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>164</td>
#     </tr>
#     <tr>
#       <td>104d2f17ef6fee50</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>147</td>
#     </tr>
#     <tr>
#       <td>f95578b01391f469</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <td>1859fd4ac75b2c97</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <td>cb457b50c9eef3b9</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <td>55ba33c099a82498</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <td>86977eaad8844018</td>
#       <td>SAFE</td>
#       <td>TOXIC</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <td>d1c6f6d44461c6ac</td>
#       <td>TOXIC</td>
#       <td>SAFE</td>
#       <td>31</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ## 12. Demo hệ thống bằng câu tự tạo
# Demo dùng **baseline đã khóa**, không tự chuyển sang model đứng đầu bảng dev.
# `confidence_proxy` là điểm hỗ trợ quyết định, **chưa phải xác suất đúng đã hiệu chỉnh**; đặc biệt với LinearSVC, đây là sigmoid của decision score.

# %%
# Chỉnh danh sách câu tự tạo để thử hệ thống; test.model là baseline đã khóa.
sample_sentences = [
    "Hôm nay trời đẹp quá, chúc mọi người một ngày vui vẻ!",
    "Dịch vụ bên bạn quá tệ, tôi rất thất vọng về cách xử lý khiếu nại.",
    "Mày ngu vừa thôi, có mỗi việc này cũng không làm xong.",
    "Bài viết này phân tích rất hay và có góc nhìn mới mẻ.",
    "Tôi không đồng ý với ý kiến này nhưng vẫn tôn trọng bạn."
]
demo_results = predict_examples(test.model, test.model_name, sample_sentences)
reports.demo(test.model_name, demo_results)
# Out:
# Demo • linear_svc • câu tự tạo, không phải dữ liệu test
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>example</th>
#       <th>synthetic_text</th>
#       <th>model</th>
#       <th>prediction</th>
#       <th>confidence_proxy</th>
#       <th>warning_level</th>
#       <th>human_review</th>
#       <th>warning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>DEMO-01</td>
#       <td>Hôm nay trời đẹp quá, chúc mọi người một ngày vui vẻ!</td>
#       <td>linear_svc</td>
#       <td>SAFE</td>
#       <td>0.7967</td>
#       <td>LOW</td>
#       <td>False</td>
#       <td>Cho phép báo cáo thủ công</td>
#     </tr>
#     <tr>
#       <td>DEMO-02</td>
#       <td>Dịch vụ bên bạn quá tệ, tôi rất thất vọng về cách xử lý khiếu nại.</td>
#       <td>linear_svc</td>
#       <td>SAFE</td>
#       <td>0.7680</td>
#       <td>LOW</td>
#       <td>False</td>
#       <td>Cho phép báo cáo thủ công</td>
#     </tr>
#     <tr>
#       <td>DEMO-03</td>
#       <td>Mày ngu vừa thôi, có mỗi việc này cũng không làm xong.</td>
#       <td>linear_svc</td>
#       <td>TOXIC</td>
#       <td>0.5906</td>
#       <td>MEDIUM</td>
#       <td>True</td>
#       <td>Chuyển human review</td>
#     </tr>
#     <tr>
#       <td>DEMO-04</td>
#       <td>Bài viết này phân tích rất hay và có góc nhìn mới mẻ.</td>
#       <td>linear_svc</td>
#       <td>SAFE</td>
#       <td>0.6554</td>
#       <td>LOW</td>
#       <td>False</td>
#       <td>Cho phép báo cáo thủ công</td>
#     </tr>
#     <tr>
#       <td>DEMO-05</td>
#       <td>Tôi không đồng ý với ý kiến này nhưng vẫn tôn trọng bạn.</td>
#       <td>linear_svc</td>
#       <td>SAFE</td>
#       <td>0.7018</td>
#       <td>LOW</td>
#       <td>False</td>
#       <td>Cho phép báo cáo thủ công</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ## 13. Neural: lịch sử huấn luyện BiLSTM / PhoBERT trên train/dev
# Mỗi epoch lưu **loss tối ưu trung bình**, **train/dev loss ở chế độ eval**, metrics train/dev đầy đủ và thời gian.
# Loss train/eval và dev/eval được đo sau epoch với cùng checkpoint để so sánh; việc đánh giá train làm tăng thời gian chạy.
# Chọn checkpoint bằng dev Macro-F1 → dev TOXIC Recall. Lưu history sau mỗi epoch để giữ tiến độ nếu lần chạy bị gián đoạn.
# Nhánh này không đọc test; kết quả test trước đó vẫn thuộc baseline đã khóa.

# %%
neural = prepare_neural(run, train_df, dev_df)
# Out:
# Neural device: cuda • Tesla T4

# %% [markdown]
# ### 13.1. BiLSTM

# %%
bilstm_result = train_bilstm(neural, learning_rate=2e-4)
# Out:
# BiLSTM: nhúng từ Word2Vec phủ 9130/9132 từ vựng (100.0%), 4.9s
# BiLSTM: trọng số lớp SAFE=0.605, TOXIC=2.889
# BiLSTM epoch 1: batch 250/752
# BiLSTM epoch 1: batch 500/752
# BiLSTM epoch 1: batch 750/752
# bilstm epoch 1/3 | train loss=0.4419, dev loss=0.4664 | train F1=0.7483, dev F1=0.7321 | dev TOXIC Recall=0.7510 | 8.3s
# BiLSTM epoch 2: batch 250/752
# BiLSTM epoch 2: batch 500/752
# BiLSTM epoch 2: batch 750/752
# bilstm epoch 2/3 | train loss=0.3511, dev loss=0.4288 | train F1=0.8079, dev F1=0.7585 | dev TOXIC Recall=0.7573 | 7.9s
# BiLSTM epoch 3: batch 250/752
# BiLSTM epoch 3: batch 500/752
# BiLSTM epoch 3: batch 750/752
# bilstm epoch 3/3 | train loss=0.2763, dev loss=0.4378 | train F1=0.8487, dev F1=0.7737 | dev TOXIC Recall=0.7386 | 8.0s
# BiLSTM: đã lưu checkpoint tốt nhất ở epoch 3

# %% [markdown]
# ### 13.2. PhoBERT

# %%
phobert_result = train_phobert(neural, learning_rate=2e-5)
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/678 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/phobert-base-v2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PhoBERT: trọng số lớp SAFE=0.605, TOXIC=2.889
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# PhoBERT epoch 1: batch 250/1503
# PhoBERT epoch 1: batch 500/1503
# PhoBERT epoch 1: batch 750/1503
# PhoBERT epoch 1: batch 1000/1503
# PhoBERT epoch 1: batch 1250/1503
# PhoBERT epoch 1: batch 1500/1503
# phobert epoch 1/3 | train loss=0.2886, dev loss=0.3620 | train F1=0.8396, dev F1=0.8101 | dev TOXIC Recall=0.8195 | 330.9s
# PhoBERT epoch 2: batch 250/1503
# PhoBERT epoch 2: batch 500/1503
# PhoBERT epoch 2: batch 750/1503
# PhoBERT epoch 2: batch 1000/1503
# PhoBERT epoch 2: batch 1250/1503
# PhoBERT epoch 2: batch 1500/1503
# phobert epoch 2/3 | train loss=0.2689, dev loss=0.5371 | train F1=0.9010, dev F1=0.8323 | dev TOXIC Recall=0.7324 | 339.2s
# PhoBERT epoch 3: batch 250/1503
# PhoBERT epoch 3: batch 500/1503
# PhoBERT epoch 3: batch 750/1503
# PhoBERT epoch 3: batch 1000/1503
# PhoBERT epoch 3: batch 1250/1503
# PhoBERT epoch 3: batch 1500/1503
# phobert epoch 3/3 | train loss=0.2041, dev loss=0.5453 | train F1=0.9183, dev F1=0.8327 | dev TOXIC Recall=0.7593 | 337.9s
# PhoBERT: đã lưu checkpoint tốt nhất ở epoch 3

# %% [markdown]
# ### 13.3. Đường học và kết quả neural tại epoch tốt nhất

# %%
reports.neural(neural)
# Out:
# Thông tin lần chạy neural
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>run_id</th>
#       <th>device</th>
#       <th>preprocessing_seconds</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20260920T101602724213Z_full_with_neural</td>
#       <td>cuda</td>
#       <td>16.2048</td>
#       <td>completed</td>
#     </tr>
#   </tbody>
# </table></div>
# Checkpoint tốt nhất, cấu hình và thời gian neural
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>best_epoch</th>
#       <th>fit_seconds</th>
#       <th>evaluation_seconds</th>
#       <th>total_seconds</th>
#       <th>vocabulary_size</th>
#       <th>max_length</th>
#       <th>epochs_ran</th>
#       <th>stopped_early</th>
#       <th>embedding</th>
#       <th>hyperparameters</th>
#       <th>checkpoint</th>
#       <th>resolved_revision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm</td>
#       <td>3</td>
#       <td>19.1271</td>
#       <td>5.0818</td>
#       <td>35.9891</td>
#       <td>9132.0000</td>
#       <td>128</td>
#       <td>3</td>
#       <td>False</td>
#       <td>{'used': True, 'algorithm': 'word2vec_skipgram', 'corpus': 'train split đã tiền xử lý', 'vector_size': 128, 'window': 5, 'min_count': 2, 'epochs': 5, 'seed': 42, 'vocabulary_covered': 9130, 'vocabulary_size': 9132, 'coverage_ratio': 0.9997809899255365, 'train_seconds': 4.858911450999983}</td>
#       <td>{'learning_rate': 0.0002, 'batch_size': 32, 'max_length': 128, 'embedding_dim': 128, 'hidden_size': 96, 'dropout': 0.3, 'min_count': 2, 'weight_decay': 0.01, 'patience': 2, 'grad_clip': 1.0, 'packed_sequence': True, 'class_weights': {'SAFE': 0.6046464849642965, 'TOXIC': 2.888995675156175}}</td>
#       <td>—</td>
#       <td>—</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>3</td>
#       <td>773.0971</td>
#       <td>234.9445</td>
#       <td>1052.5807</td>
#       <td>—</td>
#       <td>128</td>
#       <td>3</td>
#       <td>False</td>
#       <td>—</td>
#       <td>{'learning_rate': 2e-05, 'batch_size': 16, 'max_length': 128, 'weight_decay': 0.01, 'warmup_ratio': 0.1, 'patience': 2, 'grad_clip': 1.0, 'scheduler': 'linear_warmup_decay', 'class_weights': {'SAFE': 0.6046464849642965, 'TOXIC': 2.888995675156175}}</td>
#       <td>vinai/phobert-base-v2</td>
#       <td>86cd7fd4c148980922ac11a2cf5e257f2ba639e1</td>
#     </tr>
#   </tbody>
# </table></div>
# Toàn bộ lịch sử epoch; loss/metrics train và dev đo sau mỗi epoch
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>epoch</th>
#       <th>optimization_loss</th>
#       <th>train_loss</th>
#       <th>dev_loss</th>
#       <th>train_macro_f1</th>
#       <th>dev_macro_f1</th>
#       <th>dev_accuracy</th>
#       <th>dev_toxic_recall</th>
#       <th>fit_seconds</th>
#       <th>evaluation_seconds</th>
#       <th>epoch_seconds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm</td>
#       <td>1</td>
#       <td>0.5376</td>
#       <td>0.4419</td>
#       <td>0.4664</td>
#       <td>0.7483</td>
#       <td>0.7321</td>
#       <td>0.8099</td>
#       <td>0.7510</td>
#       <td>6.6612</td>
#       <td>1.6732</td>
#       <td>8.3344</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>2</td>
#       <td>0.4184</td>
#       <td>0.3511</td>
#       <td>0.4288</td>
#       <td>0.8079</td>
#       <td>0.7585</td>
#       <td>0.8346</td>
#       <td>0.7573</td>
#       <td>6.2783</td>
#       <td>1.6013</td>
#       <td>7.8796</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>3</td>
#       <td>0.3416</td>
#       <td>0.2763</td>
#       <td>0.4378</td>
#       <td>0.8487</td>
#       <td>0.7737</td>
#       <td>0.8510</td>
#       <td>0.7386</td>
#       <td>6.1876</td>
#       <td>1.8073</td>
#       <td>7.9949</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>1</td>
#       <td>0.4834</td>
#       <td>0.2886</td>
#       <td>0.3620</td>
#       <td>0.8396</td>
#       <td>0.8101</td>
#       <td>0.8735</td>
#       <td>0.8195</td>
#       <td>253.0550</td>
#       <td>77.8174</td>
#       <td>330.8724</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>2</td>
#       <td>0.3503</td>
#       <td>0.2689</td>
#       <td>0.5371</td>
#       <td>0.9010</td>
#       <td>0.8323</td>
#       <td>0.9001</td>
#       <td>0.7324</td>
#       <td>260.2455</td>
#       <td>78.9960</td>
#       <td>339.2415</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>3</td>
#       <td>0.2920</td>
#       <td>0.2041</td>
#       <td>0.5453</td>
#       <td>0.9183</td>
#       <td>0.8327</td>
#       <td>0.8978</td>
#       <td>0.7593</td>
#       <td>259.7966</td>
#       <td>78.1311</td>
#       <td>337.9277</td>
#     </tr>
#   </tbody>
# </table></div>
# Metrics tổng hợp (thang 0–1)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>samples</th>
#       <th>accuracy</th>
#       <th>macro_precision</th>
#       <th>macro_recall</th>
#       <th>macro_f1</th>
#       <th>weighted_precision</th>
#       <th>weighted_recall</th>
#       <th>weighted_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm epoch 1</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.8276</td>
#       <td>0.7234</td>
#       <td>0.8046</td>
#       <td>0.7483</td>
#       <td>0.8687</td>
#       <td>0.8276</td>
#       <td>0.8407</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 1</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8099</td>
#       <td>0.7101</td>
#       <td>0.7869</td>
#       <td>0.7321</td>
#       <td>0.8555</td>
#       <td>0.8099</td>
#       <td>0.8244</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 2</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.8737</td>
#       <td>0.7794</td>
#       <td>0.8578</td>
#       <td>0.8079</td>
#       <td>0.8988</td>
#       <td>0.8737</td>
#       <td>0.8814</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 2</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8346</td>
#       <td>0.7350</td>
#       <td>0.8044</td>
#       <td>0.7585</td>
#       <td>0.8667</td>
#       <td>0.8346</td>
#       <td>0.8451</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 3</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9028</td>
#       <td>0.8194</td>
#       <td>0.8942</td>
#       <td>0.8487</td>
#       <td>0.9200</td>
#       <td>0.9028</td>
#       <td>0.9078</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 3</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8510</td>
#       <td>0.7526</td>
#       <td>0.8072</td>
#       <td>0.7737</td>
#       <td>0.8713</td>
#       <td>0.8510</td>
#       <td>0.8583</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 1</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.8965</td>
#       <td>0.8105</td>
#       <td>0.8858</td>
#       <td>0.8396</td>
#       <td>0.9152</td>
#       <td>0.8965</td>
#       <td>0.9021</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 1</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8735</td>
#       <td>0.7843</td>
#       <td>0.8524</td>
#       <td>0.8101</td>
#       <td>0.8947</td>
#       <td>0.8735</td>
#       <td>0.8802</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 2</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9419</td>
#       <td>0.8919</td>
#       <td>0.9110</td>
#       <td>0.9010</td>
#       <td>0.9437</td>
#       <td>0.9419</td>
#       <td>0.9426</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 2</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.9001</td>
#       <td>0.8299</td>
#       <td>0.8347</td>
#       <td>0.8323</td>
#       <td>0.9008</td>
#       <td>0.9001</td>
#       <td>0.9004</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 3</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9513</td>
#       <td>0.9032</td>
#       <td>0.9356</td>
#       <td>0.9183</td>
#       <td>0.9541</td>
#       <td>0.9513</td>
#       <td>0.9522</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 3</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8978</td>
#       <td>0.8229</td>
#       <td>0.8438</td>
#       <td>0.8327</td>
#       <td>0.9016</td>
#       <td>0.8978</td>
#       <td>0.8994</td>
#     </tr>
#   </tbody>
# </table></div>
# Precision / Recall / F1 / Support từng lớp
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>label</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm epoch 1</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9456</td>
#       <td>0.8398</td>
#       <td>0.8896</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 1</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.5013</td>
#       <td>0.7693</td>
#       <td>0.6070</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 1</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9376</td>
#       <td>0.8228</td>
#       <td>0.8765</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 1</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.4827</td>
#       <td>0.7510</td>
#       <td>0.5877</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 2</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9620</td>
#       <td>0.8821</td>
#       <td>0.9203</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 2</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.5968</td>
#       <td>0.8335</td>
#       <td>0.6955</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 2</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9410</td>
#       <td>0.8516</td>
#       <td>0.8941</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 2</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.5290</td>
#       <td>0.7573</td>
#       <td>0.6229</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 3</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9733</td>
#       <td>0.9073</td>
#       <td>0.9392</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 3</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.6655</td>
#       <td>0.8811</td>
#       <td>0.7583</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 3</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9384</td>
#       <td>0.8758</td>
#       <td>0.9060</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>bilstm epoch 3</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.5669</td>
#       <td>0.7386</td>
#       <td>0.6414</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 1</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9706</td>
#       <td>0.9021</td>
#       <td>0.9351</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 1</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.6503</td>
#       <td>0.8695</td>
#       <td>0.7441</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 1</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9571</td>
#       <td>0.8854</td>
#       <td>0.9198</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 1</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.6115</td>
#       <td>0.8195</td>
#       <td>0.7004</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 2</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9711</td>
#       <td>0.9583</td>
#       <td>0.9647</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 2</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.8126</td>
#       <td>0.8638</td>
#       <td>0.8374</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 2</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9409</td>
#       <td>0.9370</td>
#       <td>0.9389</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 2</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.7189</td>
#       <td>0.7324</td>
#       <td>0.7256</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 3</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9811</td>
#       <td>0.9596</td>
#       <td>0.9702</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 3</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.8253</td>
#       <td>0.9116</td>
#       <td>0.8663</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 3</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9460</td>
#       <td>0.9283</td>
#       <td>0.9371</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>phobert epoch 3</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.6998</td>
#       <td>0.7593</td>
#       <td>0.7284</td>
#       <td>482</td>
#     </tr>
#   </tbody>
# </table></div>
# Metrics tổng hợp (thang 0–1)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>samples</th>
#       <th>accuracy</th>
#       <th>macro_precision</th>
#       <th>macro_recall</th>
#       <th>macro_f1</th>
#       <th>weighted_precision</th>
#       <th>weighted_recall</th>
#       <th>weighted_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9028</td>
#       <td>0.8194</td>
#       <td>0.8942</td>
#       <td>0.8487</td>
#       <td>0.9200</td>
#       <td>0.9028</td>
#       <td>0.9078</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8510</td>
#       <td>0.7526</td>
#       <td>0.8072</td>
#       <td>0.7737</td>
#       <td>0.8713</td>
#       <td>0.8510</td>
#       <td>0.8583</td>
#     </tr>
#   </tbody>
# </table></div>
# Precision / Recall / F1 / Support từng lớp
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>label</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9733</td>
#       <td>0.9073</td>
#       <td>0.9392</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.6655</td>
#       <td>0.8811</td>
#       <td>0.7583</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9384</td>
#       <td>0.8758</td>
#       <td>0.9060</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.5669</td>
#       <td>0.7386</td>
#       <td>0.6414</td>
#       <td>482</td>
#     </tr>
#   </tbody>
# </table></div>
# Metrics tổng hợp (thang 0–1)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>samples</th>
#       <th>accuracy</th>
#       <th>macro_precision</th>
#       <th>macro_recall</th>
#       <th>macro_f1</th>
#       <th>weighted_precision</th>
#       <th>weighted_recall</th>
#       <th>weighted_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>phobert</td>
#       <td>train</td>
#       <td>24048</td>
#       <td>0.9513</td>
#       <td>0.9032</td>
#       <td>0.9356</td>
#       <td>0.9183</td>
#       <td>0.9541</td>
#       <td>0.9513</td>
#       <td>0.9522</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8978</td>
#       <td>0.8229</td>
#       <td>0.8438</td>
#       <td>0.8327</td>
#       <td>0.9016</td>
#       <td>0.8978</td>
#       <td>0.8994</td>
#     </tr>
#   </tbody>
# </table></div>
# Precision / Recall / F1 / Support từng lớp
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>label</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>phobert</td>
#       <td>train</td>
#       <td>SAFE</td>
#       <td>0.9811</td>
#       <td>0.9596</td>
#       <td>0.9702</td>
#       <td>19886</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>train</td>
#       <td>TOXIC</td>
#       <td>0.8253</td>
#       <td>0.9116</td>
#       <td>0.8663</td>
#       <td>4162</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9460</td>
#       <td>0.9283</td>
#       <td>0.9371</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.6998</td>
#       <td>0.7593</td>
#       <td>0.7284</td>
#       <td>482</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### 13.4. Neural trên tập test
#
# Mở test **sau khi** đã khóa lựa chọn ở mục 8. Epoch tốt nhất và ngưỡng quyết định
# đều được chọn bằng tập dev; test chỉ dùng để báo cáo, không dùng để chọn lại.

# %%
neural_test = evaluate_neural_test(neural, confirm=CONFIRM_TEST_AFTER_LOCK)
# Out:
# bilstm • test Accuracy=0.8576 | Macro-F1=0.7748 | TOXIC Recall=0.7412
# phobert • test Accuracy=0.8915 | Macro-F1=0.8152 | TOXIC Recall=0.7350

# %%
reports.neural_test(neural_test)
# Out:
# Metrics tổng hợp (thang 0–1)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>samples</th>
#       <th>accuracy</th>
#       <th>macro_precision</th>
#       <th>macro_recall</th>
#       <th>macro_f1</th>
#       <th>weighted_precision</th>
#       <th>weighted_recall</th>
#       <th>weighted_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm @0.5</td>
#       <td>test</td>
#       <td>6680</td>
#       <td>0.8576</td>
#       <td>0.7520</td>
#       <td>0.8113</td>
#       <td>0.7748</td>
#       <td>0.8786</td>
#       <td>0.8576</td>
#       <td>0.8651</td>
#     </tr>
#     <tr>
#       <td>bilstm @0.65</td>
#       <td>test</td>
#       <td>6680</td>
#       <td>0.8820</td>
#       <td>0.7898</td>
#       <td>0.7950</td>
#       <td>0.7924</td>
#       <td>0.8831</td>
#       <td>0.8820</td>
#       <td>0.8826</td>
#     </tr>
#     <tr>
#       <td>phobert @0.5</td>
#       <td>test</td>
#       <td>6680</td>
#       <td>0.8915</td>
#       <td>0.8033</td>
#       <td>0.8292</td>
#       <td>0.8152</td>
#       <td>0.8968</td>
#       <td>0.8915</td>
#       <td>0.8937</td>
#     </tr>
#     <tr>
#       <td>phobert @0.65</td>
#       <td>test</td>
#       <td>6680</td>
#       <td>0.8948</td>
#       <td>0.8108</td>
#       <td>0.8231</td>
#       <td>0.8167</td>
#       <td>0.8970</td>
#       <td>0.8948</td>
#       <td>0.8958</td>
#     </tr>
#   </tbody>
# </table></div>
# Precision / Recall / F1 / Support từng lớp
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>label</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm @0.5</td>
#       <td>test</td>
#       <td>SAFE</td>
#       <td>0.9435</td>
#       <td>0.8814</td>
#       <td>0.9114</td>
#       <td>5548</td>
#     </tr>
#     <tr>
#       <td>bilstm @0.5</td>
#       <td>test</td>
#       <td>TOXIC</td>
#       <td>0.5605</td>
#       <td>0.7412</td>
#       <td>0.6383</td>
#       <td>1132</td>
#     </tr>
#     <tr>
#       <td>bilstm @0.65</td>
#       <td>test</td>
#       <td>SAFE</td>
#       <td>0.9310</td>
#       <td>0.9266</td>
#       <td>0.9288</td>
#       <td>5548</td>
#     </tr>
#     <tr>
#       <td>bilstm @0.65</td>
#       <td>test</td>
#       <td>TOXIC</td>
#       <td>0.6485</td>
#       <td>0.6634</td>
#       <td>0.6559</td>
#       <td>1132</td>
#     </tr>
#     <tr>
#       <td>phobert @0.5</td>
#       <td>test</td>
#       <td>SAFE</td>
#       <td>0.9447</td>
#       <td>0.9234</td>
#       <td>0.9339</td>
#       <td>5548</td>
#     </tr>
#     <tr>
#       <td>phobert @0.5</td>
#       <td>test</td>
#       <td>TOXIC</td>
#       <td>0.6619</td>
#       <td>0.7350</td>
#       <td>0.6965</td>
#       <td>1132</td>
#     </tr>
#     <tr>
#       <td>phobert @0.65</td>
#       <td>test</td>
#       <td>SAFE</td>
#       <td>0.9412</td>
#       <td>0.9315</td>
#       <td>0.9363</td>
#       <td>5548</td>
#     </tr>
#     <tr>
#       <td>phobert @0.65</td>
#       <td>test</td>
#       <td>TOXIC</td>
#       <td>0.6804</td>
#       <td>0.7147</td>
#       <td>0.6971</td>
#       <td>1132</td>
#     </tr>
#   </tbody>
# </table></div>
# Ngưỡng quyết định tinh chỉnh trên DEV rồi áp nguyên vào TEST
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>threshold</th>
#       <th>chọn trên</th>
#       <th>tiêu chí</th>
#       <th>dev_macro_f1</th>
#       <th>dev_toxic_f1</th>
#       <th>test_macro_f1</th>
#       <th>test_toxic_recall</th>
#       <th>test_toxic_f1</th>
#       <th>test_macro_f1_@0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bilstm</td>
#       <td>0.6500</td>
#       <td>dev</td>
#       <td>toxic_f1</td>
#       <td>0.7902</td>
#       <td>0.6563</td>
#       <td>0.7924</td>
#       <td>0.6634</td>
#       <td>0.6559</td>
#       <td>0.7748</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>0.6500</td>
#       <td>dev</td>
#       <td>toxic_f1</td>
#       <td>0.8426</td>
#       <td>0.7429</td>
#       <td>0.8167</td>
#       <td>0.7147</td>
#       <td>0.6971</td>
#       <td>0.8152</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ## 14. Tổng hợp và so sánh
# Bảng tổng hợp dùng cùng tập **dev**. Model đứng đầu dev trong 5 mô hình không tự thay thế baseline test/demo.
# Thời gian fit baseline gồm tiền xử lý + TF-IDF; neural là tổng bước tối ưu qua các epoch, không gồm tải checkpoint và tiền xử lý chung.
# Vì vậy thời gian có mục đích mô tả lần chạy, không phải benchmark tốc độ công bằng giữa kiến trúc.

# %%
leaderboard = reports.comparison(baselines, neural, test, neural_test=neural_test)
# Out:
# Bảng tổng hợp trên DEV (giá trị lưu không bị làm tròn)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>type</th>
#       <th>best_epoch</th>
#       <th>train_macro_f1</th>
#       <th>dev_accuracy</th>
#       <th>dev_macro_f1</th>
#       <th>dev_toxic_recall</th>
#       <th>dev_toxic_f1</th>
#       <th>fit_seconds</th>
#       <th>evaluation_seconds</th>
#       <th>test_and_demo_model</th>
#       <th>test_accuracy</th>
#       <th>test_macro_f1</th>
#       <th>test_toxic_recall</th>
#       <th>test_toxic_f1</th>
#       <th>train_minus_dev_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>phobert</td>
#       <td>Neural</td>
#       <td>3.0000</td>
#       <td>0.9183</td>
#       <td>0.8978</td>
#       <td>0.8327</td>
#       <td>0.7593</td>
#       <td>0.7284</td>
#       <td>773.0971</td>
#       <td>234.9445</td>
#       <td>False</td>
#       <td>0.8915</td>
#       <td>0.8152</td>
#       <td>0.7350</td>
#       <td>0.6965</td>
#       <td>0.0856</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>ML baseline</td>
#       <td>—</td>
#       <td>0.9602</td>
#       <td>0.8690</td>
#       <td>0.7923</td>
#       <td>0.7241</td>
#       <td>0.6660</td>
#       <td>16.1263</td>
#       <td>16.4925</td>
#       <td>True</td>
#       <td>0.8683</td>
#       <td>0.7785</td>
#       <td>0.6837</td>
#       <td>0.6376</td>
#       <td>0.1679</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>ML baseline</td>
#       <td>—</td>
#       <td>0.9148</td>
#       <td>0.8630</td>
#       <td>0.7911</td>
#       <td>0.7656</td>
#       <td>0.6685</td>
#       <td>15.1772</td>
#       <td>16.8759</td>
#       <td>False</td>
#       <td>—</td>
#       <td>—</td>
#       <td>—</td>
#       <td>—</td>
#       <td>0.1237</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>Neural</td>
#       <td>3.0000</td>
#       <td>0.8487</td>
#       <td>0.8510</td>
#       <td>0.7737</td>
#       <td>0.7386</td>
#       <td>0.6414</td>
#       <td>19.1271</td>
#       <td>5.0818</td>
#       <td>False</td>
#       <td>0.8576</td>
#       <td>0.7748</td>
#       <td>0.7412</td>
#       <td>0.6383</td>
#       <td>0.0750</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>ML baseline</td>
#       <td>—</td>
#       <td>0.8319</td>
#       <td>0.8641</td>
#       <td>0.6808</td>
#       <td>0.2946</td>
#       <td>0.4389</td>
#       <td>15.5650</td>
#       <td>17.2299</td>
#       <td>False</td>
#       <td>—</td>
#       <td>—</td>
#       <td>—</td>
#       <td>—</td>
#       <td>0.1511</td>
#     </tr>
#   </tbody>
# </table></div>
# Metrics tổng hợp (thang 0–1)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>samples</th>
#       <th>accuracy</th>
#       <th>macro_precision</th>
#       <th>macro_recall</th>
#       <th>macro_f1</th>
#       <th>weighted_precision</th>
#       <th>weighted_recall</th>
#       <th>weighted_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_svc</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8690</td>
#       <td>0.7767</td>
#       <td>0.8125</td>
#       <td>0.7923</td>
#       <td>0.8791</td>
#       <td>0.8690</td>
#       <td>0.8730</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8630</td>
#       <td>0.7691</td>
#       <td>0.8250</td>
#       <td>0.7911</td>
#       <td>0.8814</td>
#       <td>0.8630</td>
#       <td>0.8694</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8641</td>
#       <td>0.8625</td>
#       <td>0.6421</td>
#       <td>0.6808</td>
#       <td>0.8637</td>
#       <td>0.8641</td>
#       <td>0.8355</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8510</td>
#       <td>0.7526</td>
#       <td>0.8072</td>
#       <td>0.7737</td>
#       <td>0.8713</td>
#       <td>0.8510</td>
#       <td>0.8583</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>dev</td>
#       <td>2672</td>
#       <td>0.8978</td>
#       <td>0.8229</td>
#       <td>0.8438</td>
#       <td>0.8327</td>
#       <td>0.9016</td>
#       <td>0.8978</td>
#       <td>0.8994</td>
#     </tr>
#   </tbody>
# </table></div>
# Precision / Recall / F1 / Support từng lớp
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>split</th>
#       <th>label</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_svc</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9368</td>
#       <td>0.9009</td>
#       <td>0.9185</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.6166</td>
#       <td>0.7241</td>
#       <td>0.6660</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9449</td>
#       <td>0.8845</td>
#       <td>0.9137</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>logistic_regression</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.5932</td>
#       <td>0.7656</td>
#       <td>0.6685</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.8644</td>
#       <td>0.9895</td>
#       <td>0.9227</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>multinomial_nb</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.8606</td>
#       <td>0.2946</td>
#       <td>0.4389</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9384</td>
#       <td>0.8758</td>
#       <td>0.9060</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.5669</td>
#       <td>0.7386</td>
#       <td>0.6414</td>
#       <td>482</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>dev</td>
#       <td>SAFE</td>
#       <td>0.9460</td>
#       <td>0.9283</td>
#       <td>0.9371</td>
#       <td>2190</td>
#     </tr>
#     <tr>
#       <td>phobert</td>
#       <td>dev</td>
#       <td>TOXIC</td>
#       <td>0.6998</td>
#       <td>0.7593</td>
#       <td>0.7284</td>
#       <td>482</td>
#     </tr>
#   </tbody>
# </table></div>
# Model đứng đầu DEV: phobert (Macro-F1=0.8327)
# Model TEST và DEMO đã khóa: linear_svc (test Accuracy=0.8683; test Macro-F1=0.7785)
#
# Bảng so sánh trên TEST (baseline đã khóa + neural chấm sau khi khóa)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>type</th>
#       <th>dev_macro_f1</th>
#       <th>test_accuracy</th>
#       <th>test_macro_f1</th>
#       <th>test_toxic_recall</th>
#       <th>test_toxic_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>phobert</td>
#       <td>Neural</td>
#       <td>0.8327</td>
#       <td>0.8915</td>
#       <td>0.8152</td>
#       <td>0.7350</td>
#       <td>0.6965</td>
#     </tr>
#     <tr>
#       <td>linear_svc</td>
#       <td>ML baseline</td>
#       <td>0.7923</td>
#       <td>0.8683</td>
#       <td>0.7785</td>
#       <td>0.6837</td>
#       <td>0.6376</td>
#     </tr>
#     <tr>
#       <td>bilstm</td>
#       <td>Neural</td>
#       <td>0.7737</td>
#       <td>0.8576</td>
#       <td>0.7748</td>
#       <td>0.7412</td>
#       <td>0.6383</td>
#     </tr>
#   </tbody>
# </table></div>
# Model đứng đầu TEST: phobert (test Macro-F1=0.8152)

# %% [markdown]
# ## 15. Artifacts, tái lập và kết luận
# Tất cả bảng/biểu đồ đã được xuất dưới dạng **CSV/PNG** trong thư mục lần chạy này; JSON giữ metrics đầy đủ.
# `neural_history.json` chứa metrics train/dev của từng epoch, loss và thời gian. Checkpoint tốt nhất được lưu riêng.
# Bảng dưới liệt kê đầy đủ đường dẫn, kích thước và loại file; file ZIP báo cáo gồm JSON/CSV/PNG, không gồm checkpoint lớn.
# Kết quả là reproduction/post-hoc; không dùng kết quả test để điều chỉnh model trong lần chạy này.

# %%
report_archive = reports.export()
# Out:
# Các artifacts đã tạo (không liệt kê chính bảng inventory và ZIP tạo sau)
# <div style="overflow:auto;max-height:650px"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>file</th>
#       <th>bytes</th>
#       <th>size_MiB</th>
#       <th>type</th>
#       <th>absolute_path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>all_models_comparison.png</td>
#       <td>201633</td>
#       <td>0.1923</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/all_models_comparison.png</td>
#     </tr>
#     <tr>
#       <td>all_models_dev_leaderboard.csv</td>
#       <td>1366</td>
#       <td>0.0013</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/all_models_dev_leaderboard.csv</td>
#     </tr>
#     <tr>
#       <td>all_models_dev_leaderboard.json</td>
#       <td>3265</td>
#       <td>0.0031</td>
#       <td>.json</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/all_models_dev_leaderboard.json</td>
#     </tr>
#     <tr>
#       <td>all_models_dev_per_class.csv</td>
#       <td>879</td>
#       <td>0.0008</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/all_models_dev_per_class.csv</td>
#     </tr>
#     <tr>
#       <td>all_models_dev_summary.csv</td>
#       <td>886</td>
#       <td>0.0008</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/all_models_dev_summary.csv</td>
#     </tr>
#     <tr>
#       <td>all_models_test_leaderboard.csv</td>
#       <td>422</td>
#       <td>0.0004</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/all_models_test_leaderboard.csv</td>
#     </tr>
#     <tr>
#       <td>audit_test.json</td>
#       <td>492</td>
#       <td>0.0005</td>
#       <td>.json</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_test.json</td>
#     </tr>
#     <tr>
#       <td>audit_test_distributions.png</td>
#       <td>65159</td>
#       <td>0.0621</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_test_distributions.png</td>
#     </tr>
#     <tr>
#       <td>audit_test_labels.csv</td>
#       <td>314</td>
#       <td>0.0003</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_test_labels.csv</td>
#     </tr>
#     <tr>
#       <td>audit_test_stats.csv</td>
#       <td>205</td>
#       <td>0.0002</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_test_stats.csv</td>
#     </tr>
#     <tr>
#       <td>audit_train_dev.json</td>
#       <td>944</td>
#       <td>0.0009</td>
#       <td>.json</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_train_dev.json</td>
#     </tr>
#     <tr>
#       <td>audit_train_dev_distributions.png</td>
#       <td>73752</td>
#       <td>0.0703</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_train_dev_distributions.png</td>
#     </tr>
#     <tr>
#       <td>audit_train_dev_labels.csv</td>
#       <td>594</td>
#       <td>0.0006</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_train_dev_labels.csv</td>
#     </tr>
#     <tr>
#       <td>audit_train_dev_stats.csv</td>
#       <td>267</td>
#       <td>0.0003</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/audit_train_dev_stats.csv</td>
#     </tr>
#     <tr>
#       <td>baseline_comparison.png</td>
#       <td>67996</td>
#       <td>0.0648</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/baseline_comparison.png</td>
#     </tr>
#     <tr>
#       <td>baseline_dev_confusions.png</td>
#       <td>119531</td>
#       <td>0.1140</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/baseline_dev_confusions.png</td>
#     </tr>
#     <tr>
#       <td>baseline_per_class.csv</td>
#       <td>1100</td>
#       <td>0.0010</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/baseline_per_class.csv</td>
#     </tr>
#     <tr>
#       <td>baseline_ranking.csv</td>
#       <td>493</td>
#       <td>0.0005</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/baseline_ranking.csv</td>
#     </tr>
#     <tr>
#       <td>baseline_summary.csv</td>
#       <td>1063</td>
#       <td>0.0010</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/baseline_summary.csv</td>
#     </tr>
#     <tr>
#       <td>baseline_train_confusions.png</td>
#       <td>120589</td>
#       <td>0.1150</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/baseline_train_confusions.png</td>
#     </tr>
#     <tr>
#       <td>bilstm_best_confusions.png</td>
#       <td>87869</td>
#       <td>0.0838</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/bilstm_best_confusions.png</td>
#     </tr>
#     <tr>
#       <td>bilstm_best_per_class.csv</td>
#       <td>367</td>
#       <td>0.0003</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/bilstm_best_per_class.csv</td>
#     </tr>
#     <tr>
#       <td>bilstm_best_summary.csv</td>
#       <td>417</td>
#       <td>0.0004</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/bilstm_best_summary.csv</td>
#     </tr>
#     <tr>
#       <td>bilstm_binary.best.pt</td>
#       <td>5562301</td>
#       <td>5.3046</td>
#       <td>.pt</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/bilstm_binary.best.pt</td>
#     </tr>
#     <tr>
#       <td>bilstm_dev_threshold_sweep.csv</td>
#       <td>1954</td>
#       <td>0.0019</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/bilstm_dev_threshold_sweep.csv</td>
#     </tr>
#     <tr>
#       <td>bilstm_dev_threshold_sweep.png</td>
#       <td>87743</td>
#       <td>0.0837</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/bilstm_dev_threshold_sweep.png</td>
#     </tr>
#     <tr>
#       <td>bilstm_learning_curves.png</td>
#       <td>115517</td>
#       <td>0.1102</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/bilstm_learning_curves.png</td>
#     </tr>
#     <tr>
#       <td>demo_predictions.csv</td>
#       <td>848</td>
#       <td>0.0008</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/demo_predictions.csv</td>
#     </tr>
#     <tr>
#       <td>demo_predictions.json</td>
#       <td>1808</td>
#       <td>0.0017</td>
#       <td>.json</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/demo_predictions.json</td>
#     </tr>
#     <tr>
#       <td>demo_predictions.png</td>
#       <td>45357</td>
#       <td>0.0433</td>
#       <td>.png</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/demo_predictions.png</td>
#     </tr>
#     <tr>
#       <td>dev_results.json</td>
#       <td>7031</td>
#       <td>0.0067</td>
#       <td>.json</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/dev_results.json</td>
#     </tr>
#     <tr>
#       <td>error_analysis.json</td>
#       <td>4106</td>
#       <td>0.0039</td>
#       <td>.json</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/error_analysis.json</td>
#     </tr>
#     <tr>
#       <td>linear_svc.joblib</td>
#       <td>560370</td>
#       <td>0.5344</td>
#       <td>.joblib</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/linear_svc.joblib</td>
#     </tr>
#     <tr>
#       <td>manifest.csv</td>
#       <td>433</td>
#       <td>0.0004</td>
#       <td>.csv</td>
#       <td>/content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/manifest.csv</td>
#     </tr>
#     <tr>
#       <t
# Đã lưu 73 artifacts trước inventory/ZIP.
# Thư mục: /content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural
# ZIP báo cáo: /content/vihsd_ai_outputs/20260920T101602724213Z_full_with_neural/reports.zip (1.30 MiB)
# Colab: mở bảng Files bên trái → thư mục lần chạy → reports.zip → Download.

# %% [markdown]
# ## 16. Ô thử nhanh — nhập câu mới và xem kết quả
#
# Dùng để demo trực tiếp mà **không cần Run all**. Model đã nằm sẵn trong bộ nhớ ở biến
# `test.model`, nên chỉ cần sửa câu rồi bấm chạy lại đúng cell bên dưới (`Shift + Enter`),
# mất chưa tới một giây.
#
# Điều kiện: đã chạy tới ít nhất **mục 9–10** trong phiên hiện tại. Nếu vừa Restart session
# thì phải chạy lại từ đầu.

# %%
# ── THỬ NHIỀU CÂU CÙNG LÚC ──────────────────────────────────────────
# Sửa danh sách bên dưới rồi chạy lại CHỈ cell này.

cau_moi = [
    "Cảm ơn shop đã giao hàng nhanh, đóng gói rất cẩn thận.",
    "Nhóm mình vừa nộp đồ án xong, nhẹ cả người.",
    "Thằng này ngu như bò, nói mãi không hiểu.",
    "Phim này dở tệ, đạo diễn làm ăn kiểu gì vậy trời.",
    "Bạn nói cũng có lý nhưng mình nghĩ khác một chút.",
]

if "test" not in dir():
    raise RuntimeError(
        "Chưa có model trong bộ nhớ. Chạy các cell phía trên trước "
        "(Runtime > Run before), hoặc Run all nếu vừa Restart session."
    )

print(f"Model đang dùng: {test.model_name}")
print("=" * 76)
for i, cau in enumerate(cau_moi, 1):
    kq = system_decision(test.model, test.model_name, cau)
    dau = "[!]" if kq["label"] == "TOXIC" else "[ok]"
    print(f"{i}. {cau}")
    print(f"   {dau} {kq['label']:<5} | tin cay {kq['confidence_proxy']:.1%} "
          f"| muc {kq['warning_level']:<6} | can nguoi xem lai: "
          f"{'CO' if kq['human_review'] else 'khong'}")
    print()
# Out:
# Model đang dùng: linear_svc
# ============================================================================
# 1. Cảm ơn shop đã giao hàng nhanh, đóng gói rất cẩn thận.
#    [ok] SAFE  | tin cay 76.1% | muc LOW    | can nguoi xem lai: khong
#
# 2. Nhóm mình vừa nộp đồ án xong, nhẹ cả người.
#    [ok] SAFE  | tin cay 60.1% | muc REVIEW | can nguoi xem lai: CO
#
# 3. Thằng này ngu như bò, nói mãi không hiểu.
#    [!] TOXIC | tin cay 91.9% | muc HIGH   | can nguoi xem lai: CO
#
# 4. Phim này dở tệ, đạo diễn làm ăn kiểu gì vậy trời.
#    [ok] SAFE  | tin cay 73.3% | muc LOW    | can nguoi xem lai: khong
#
# 5. Bạn nói cũng có lý nhưng mình nghĩ khác một chút.
#    [ok] SAFE  | tin cay 78.7% | muc LOW    | can nguoi xem lai: khong
